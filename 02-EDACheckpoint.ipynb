# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# - Ryo Sakai: Data Visualization and Interpretation
# - Servando Lara: Data Visualization and Interpretation
# - Brook Isaac:
# - Kota Fukuda: Data Visualization and Interpretation
# - Elisey Ovchinnikov: Data Visualization and Interpretation

# %% [markdown]
# # Research Question

# %% [markdown]
# How well can season-to-season changes in professional male soccer players’ inflation-adjusted market values (as reported by Transfermarkt) from 2013–2023 be predicted using age, primary playing position (goalkeeper, defender, midfielder, forward), total league minutes played, and standardized performance metrics (goals, assists, expected goals, expected assists, key passes, defensive actions per 90)?
#
# Among these variables, which are the strongest predictors of positive versus negative changes in market value between consecutive seasons?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Professional soccer operates as a global labor market in which player valuations influence transfers, wages, sponsorship visibility, and long-term club strategy. Top European leagues generate billions of dollars annually in revenue, and transfer spending alone regularly exceeds several billion euros per season.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) In this context, how players are valued has real economic consequences for clubs, agents, and players themselves. Because actual transfer fees only materialize when a transfer occurs, researchers and analysts often rely on publicly available “market value” estimates as a consistent proxy for how the market rates a player at a given moment. These values allow large-scale cross-league and cross-season statistical analysis that would not be possible using transfer fees alone.
#
# A widely used public source of such estimates is Transfermarkt, which publishes crowd-informed market values. Transfermarkt explicitly distinguishes its estimates from realized transfer fees and describes its valuation process as combining pricing logic with structured, moderated community discussion.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) This is crucial for our project: it implies that market value captures meaningful signals (age, contract status, performance, reputation) but may also reflect perception-based biases such as league visibility, media exposure, or hype. Thus, market value is best understood not as a “true” intrinsic worth, but as an observable outcome of a social and economic evaluation process.
#
# Prior academic research has investigated which factors explain player market value. A recent systematic review synthesizes evidence that performance metrics, age, positional role, contract characteristics, and contextual variables all contribute to valuation patterns.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) Müller et al. (2017) developed a data-driven framework to estimate market values across multiple European leagues and demonstrated that statistical modeling can reproduce meaningful valuation patterns using performance and contextual indicators.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) Their work shows that valuation is partially predictable and structured, rather than arbitrary.
#
# However, much of the existing literature focuses either on specific subsets of leagues (e.g., top European competitions) or on predictive accuracy rather than interpretability. In other words, prior work often asks: Can we estimate market value? Our project instead emphasizes: Which measurable attributes are most strongly associated with market value in our dataset, and how do contextual factors compare to on-field performance? By focusing on interpretability within a regression-style framework, we aim to clarify the relative contribution of performance, demographic, and contextual predictors rather than maximizing prediction alone.
#
# Researchers have also documented structural effects that may influence valuation. For example, studies of relative age effects find that players born earlier in the selection year may have higher market values in youth contexts, suggesting that developmental structures shape perceived value.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) This highlights a broader concern: even when performance metrics are included, market value may embed selection effects and institutional bias. Additionally, competing “algorithmic valuation” proposals—such as those referencing CIES-style models incorporating age and contract length—demonstrate that valuation is multi-factor and contested, with no universally accepted formula.<a name="cite_ref-6"></a>[<sup>6</sup>](#cite_note-6)
#
# These prior studies motivate and delimit our contribution. Rather than proposing a new proprietary valuation model or claiming to identify a “true” player worth, our goal is to empirically examine associations between measurable player attributes (performance statistics, playing time, age, position, and league/club context) and publicly reported market value within our dataset. By situating our analysis within this broader literature, we treat market value as a socially informed economic signal and focus on interpreting patterns rather than asserting causal or normative conclusions.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Franceschi, M. et al. (2024). Determinants of football players’ valuation: A systematic review. Journal of Economic Surveys. https://onlinelibrary.wiley.com/doi/10.1111/joes.12552
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Transfermarkt. (2021). Transfermarkt Market Value explained – How is it determined? https://www.transfermarkt.co.in/transfermarkt-market-value-explained-how-is-it-determined-/view/news/385100
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Franceschi, M. et al. (2024). Systematic review (as above).
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Müller, O., Simons, A., & Weinmann, M. (2017). Beyond crowd judgments: Data-driven estimation of market value in association football. European Journal of Operational Research. https://www.sciencedirect.com/science/article/pii/S0377221717304332
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Romann, M. et al. (2021). How Relative Age Effects Associate with Football Players’ Market Values. Frontiers in Sports and Active Living. https://pmc.ncbi.nlm.nih.gov/articles/PMC8309691/
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6) ssociated Press. (2023). Infantino refloats idea of using algorithm to set soccer player transfer fees. https://apnews.com/article/6b7f4c40581e08e69e4198bdcd579773

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that season-to-season percentage changes in players’ inflation-adjusted market value (Transfermarkt, 2013–2023) are significantly predicted by age and standardized performance metrics, including goals per 90 minutes and assists per 90 minutes, after controlling for total league minutes played and primary playing position (goalkeeper, defender, midfielder, forward). Specifically, we expect a nonlinear relationship between age and market value change (with younger players exhibiting larger positive changes), and a positive linear association between offensive performance metrics and market value growth.
#
# Additionally, we hypothesize that nationality, operationalized as a categorical variable grouped by major footballing regions (e.g., Top-5 European leagues vs. non–Top-5 regions), will remain a statistically significant predictor in a multivariate regression model, reflecting differences in league exposure and market demand.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: Football Data From Transfermarkt: appearances.csv
#   - Link to the dataset: https://www.kaggle.com/datasets/davidcariboo/player-scores?select=appearances.csv
#   - Number of observations: 1.73 million
#   - Number of variables: 13
#   - Description of the variables most relevant to this project:
#     - player_id → Unique identifier (used to merge with players.csv)
#     - game_id → Match identifier
#     - minutes_played → Playing time (important for standardizing performance)
#     - goals → Offensive contribution
#     - assists → Creative contribution
#     - yellow_cards / red_cards → Discipline metrics
#     - competition_id → League context
#   - Descriptions of any shortcomings this dataset has with repsect to the project
#     - Only includes basic statistics (goals, assists, minutes, yellow/red cards)
#     - Lacks contextual match information (opponent strength, match importance, tactics)
#     - Performance is not adjusted for position, making cross-position comparisons biased
# - Dataset #2
#   - Dataset Name: Football Data From Transfermarkt: players.csv
#   - Link to the dataset: https://www.kaggle.com/datasets/davidcariboo/player-scores?select=players.csv
#   - Number of observations: 34.3 thousand
#   - Number of variables: 23
#   - Description of the variables most relevant to this project:
#     - player_id → Key merge variable
#     - date_of_birth → Used to compute age
#     - position → Controls for positional differences
#     - height → Physical characteristic
#     - nationality → Country effects
#     - market_value (if included in version) → Proxy for valuation
#   - Descriptions of any shortcomings this dataset has with repsect to the project
#     - Position categories may be broad and not role-specific
#     - Lacks psychological or leadership attributes that may affect valuation
#
# - Dataset #3
#   - Dataset Name: Football Data From Transfermarkt: players_valuation.csv
#   - Link to the dataset: https://www.kaggle.com/datasets/davidcariboo/player-scores?select=players_valuations.csv
#   - Number of observations: 44.7 thousand
#   - Number of variables: 6
#   - Description of the variables most relevant to this project:
#     - player_id → Key merge variable
#     - market_value/date  → history of market value, market value for each season

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# %pip install gdown
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gdown
from pathlib import Path

outdir = Path("data/00-raw")
outdir.mkdir(parents=True, exist_ok=True)

gdown.download(id="1glWRGjrI7UGl0QtIuEpLdaHaB0fstUui", output=str(outdir/"player_valuations.csv"), quiet=False)
gdown.download(id="1k7ya1sIqJPVWzJb7mGhZDRO4HuIvRUuF", output=str(outdir/"appearances.csv"), quiet=False)
gdown.download(id="1RvbHJxP0Nt9cdzF8LJdFuZsArVyUVlj3", output=str(outdir/"players.csv"), quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1glWRGjrI7UGl0QtIuEpLdaHaB0fstUui
# To: /home/selara/Group101_WI26/data/00-raw/player_valuations.csv
# 100%|██████████| 21.7M/21.7M [00:00<00:00, 48.9MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1k7ya1sIqJPVWzJb7mGhZDRO4HuIvRUuF
# From (redirected): https://drive.google.com/uc?id=1k7ya1sIqJPVWzJb7mGhZDRO4HuIvRUuF&confirm=t&uuid=49c25506-4029-496a-8a23-a4a6ce4360d4
# To: /home/selara/Group101_WI26/data/00-raw/appearances.csv
# 100%|██████████| 136M/136M [00:01<00:00, 92.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1RvbHJxP0Nt9cdzF8LJdFuZsArVyUVlj3
# To: /home/selara/Group101_WI26/data/00-raw/players.csv
# 100%|██████████| 11.9M/11.9M [00:00<00:00, 35.4MB/s]
# 'data/00-raw/players.csv'

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
#%pip install requests tqdm

#import sys
#sys.path.append('./modules') # this tells python where to look for modules to import

#import get_data # this is where we get the function we need to download data

# # replace the urls and filenames in this list with your actual datafiles
# # yes you can use Google drive share links or whatever
# # format is a list of dictionaries; 
# # each dict has keys of 
# #   'url' where the resource is located
# #   'filename' for the local filename where it will be stored 
# datafiles = [
#      {'url': 'https://drive.google.com/uc?export=download&id=1glWRGjrI7UGl0QtIuEpLdaHaB0fstUui', 'filename': 'player_valuations.csv'},
#     {'url': 'https://drive.google.com/file/d/1k7ya1sIqJPVWzJb7mGhZDRO4HuIvRUuF', 'filename': 'appearances.csv'},
#     {'url': 'https://drive.google.com/uc?export=download&id=1RvbHJxP0Nt9cdzF8LJdFuZsArVyUVlj3', 'filename': 'players.csv'},
# ]

# get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# # Important Metrics and Interpretation – Raw Datasets
#
# This project begins with three raw datasets:
#
# 1. `players.csv` – Player demographic and market value snapshot
# 2. `appearances.csv` – Match-level performance data
# 3. `player_valuations.csv` – Historical market value time series
#
# Each dataset serves a distinct role and contains variables with different units, meanings, and limitations.
#
# ---
#
# # Dataset 1: Players (players.csv)
#
# This dataset contains one row per professional male soccer player, representing their most recent recorded season.
#
# ## Important Variables
#
# ### 1. market_value_in_eur
# **Unit:** Euros (nominal, not inflation-adjusted)
#
# Represents the player's estimated current market value as reported by Transfermarkt.
#
# Typical ranges:
# - Youth/reserve players: €0–€1M
# - Mid-tier professionals: €1M–€20M
# - Top-league starters: €20M–€80M
# - Elite players: €80M–€200M+
#
# This is not a transaction price. It is a publicly estimated valuation and may reflect:
# - Media exposure
# - Reputation
# - Recent performance
# - Contract length
#
# Values above €200M are rare and typically associated with global superstars.
#
# ---
#
# ### 2. highest_market_value_in_eur
# **Unit:** Euros
#
# The highest recorded estimated market value in the player's career history.
# This reflects peak perceived valuation and can serve as a proxy for career ceiling.
#
# ---
#
# ### 3. last_season
# **Unit:** Season end year (integer)
#
# Represents the most recent season in which the player appeared in the dataset.
# For European leagues, season 2023 typically corresponds to the 2022–2023 season.
#
# ---
#
# ### 4. position
# Categorical variable describing player role (e.g., Forward, Defender, Goalkeeper, Midfielder).
#
# Economic interpretation:
# - Forwards typically command higher valuations due to scoring output.
# - Goalkeepers often have lower volatility in valuation.
# - Defensive players may be undervalued relative to attacking statistics.
#
# ---
#
# ### 5. date_of_birth
# Used to compute age.
# Age is critical because player value typically follows a lifecycle pattern:
# - Rapid increase during early 20s
# - Peak around 23–27
# - Gradual decline after 28–30
#
# ---
#
# ### 6. height_in_cm
# **Unit:** Centimeters
#
# Physical attribute that may correlate with position (e.g., taller goalkeepers/defenders).
#
# ---
#
# ## Major Concerns (Players Dataset)
#
# 1. **Snapshot Bias**
#    This dataset captures players at their most recent season only. It does not provide full season-by-season market value history.
#
# 2. **Estimated Valuation, Not Real Prices**
#    Market value reflects perception rather than actual transfer fee.
#
# 3. **Missing Values**
#    Notable missingness exists in:
#    - agent_name
#    - contract_expiration_date
#    - height_in_cm
#    - market_value_in_eur (approx. 8–10%)
#
# 4. **Selection Bias**
#    Players tracked are mostly from major competitions. Lower-tier leagues may be underrepresented.
#
# ---
#
# # Dataset 2: Appearances (appearances.csv)
#
# This dataset contains match-level performance data. Each row represents one player appearance in one game.
#
# ## Important Variables
#
# ### 1. minutes_played
# **Unit:** Minutes
#
# Indicates how long the player participated in that match.
# Range:
# - 0–15 → brief substitute appearance
# - 45 → half played
# - 90 → full match
# - 120 → includes extra time
#
# Total seasonal minutes reflect:
# - Player importance
# - Injury status
# - Coach trust
#
# ---
#
# ### 2. goals
# **Unit:** Count per match
#
# Number of goals scored in that match.
# For most players:
# - 0 goals in majority of matches
# - Multi-goal games are rare
#
# Season totals:
# - 0–3 → defenders
# - 5–15 → strong attacking contributors
# - 20+ → elite scoring season
#
# ---
#
# ### 3. assists
# **Unit:** Count per match
#
# Number of credited assists in that match.
# Season totals:
# - 0–3 → defensive players
# - 5–10 → productive creative players
# - 15+ → elite playmaking season
#
# ---
#
# ### 4. yellow_cards / red_cards
# **Unit:** Count per match
#
# Disciplinary events.
# - Yellow cards indicate minor infractions
# - Red cards indicate serious misconduct or denial of scoring opportunity
#
# High card counts may signal aggressive style or disciplinary issues.
#
# ---
#
# ### 5. date
# Match date.
# Used to derive season (European season spans July–June).
#
# ---
#
# ## Major Concerns (Appearances Dataset)
#
# 1. **Match-Level Granularity**
#    Raw data is match-level. It must be aggregated to season-level before analysis.
#
# 2. **No Advanced Metrics**
#    The dataset does not include:
#    - Expected goals (xG)
#    - Expected assists (xA)
#    - Key passes
#    - Defensive actions
#
#    Without these, performance is measured only by realized outcomes (goals/assists), which may reflect finishing luck rather than underlying quality.
#
# 3. **Competition Heterogeneity**
#    Includes multiple competitions via `competition_id`. Differences in league quality may influence performance comparability.
#
# 4. **Survivorship Bias**
#    Only recorded appearances are included. Injured players or unused substitutes are underrepresented.
#
# ---
#
# # Dataset 3: Player Valuations (player_valuations.csv)
#
# This dataset contains historical market valuations over time.
#
# ## Important Variables
#
# ### 1. market_value_in_eur
# **Unit:** Euros (nominal)
#
# Represents estimated market value at a specific date.
#
# Because this dataset contains multiple valuation dates per player, it allows construction of:
#
# - Season-end valuations
# - Season-to-season value changes
#
# ---
#
# ### 2. date
# Valuation date.
# Used to assign valuation to a season (e.g., closest to June 30).
#
# ---
#
# ## Major Concerns (Valuations Dataset)
#
# 1. **Non-Transaction Based**
#    Market values are subjective estimates, not actual transfer prices.
#
# 2. **Irregular Valuation Timing**
#    Some players have many valuation updates; others have sparse updates.
#    This creates uneven temporal resolution.
#
# 3. **Market Hype Effects**
#    Media exposure, nationality, and club prestige may inflate perceived value independent of performance.
#
# 4. **Football-Specific Inflation**
#    Transfer markets inflate faster than general CPI.
#    Inflation adjustment using macroeconomic CPI may not fully capture football-specific price dynamics.
#
# ---
#
# # Overall Structural Concerns
#
# Across all raw datasets:
#
# - The data reflects **professional male players in tracked competitions**, not the entire global soccer population.
# - Lower leagues and less visible competitions may be underrepresented.
# - Market value is a perceived economic measure, not a realized transaction price.
# - Performance metrics are outcome-based (goals, assists) and lack advanced expected-value metrics.
#
# ---
#
# # Summary
#
# The raw datasets collectively provide:
#
# - Player demographic and positional information
# - Match-level performance data
# - Historical market valuations
#
# However, raw data requires:
# - Season derivation from dates
# - Aggregation to player-season level
# - Selection of season-end valuations
# - Inflation adjustment
# - Handling of missing and irregular valuation updates
#
# Only after these steps can meaningful season-to-season valuation dynamics be analyzed.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np
from pathlib import Path

RAW_DIR = Path("data/00-raw")
INTERIM_DIR = Path("data/01-interim")
PROCESSED_DIR = Path("data/02-processed")


players = pd.read_csv(RAW_DIR/"players.csv")
perf = pd.read_csv(RAW_DIR/"appearances.csv")

def zscore(s):
    s = pd.to_numeric(s, errors="coerce")
    return (s - s.mean()) / s.std(ddof=0)

def winsorize(s, p_low=0.01, p_high=0.99):
    s = pd.to_numeric(s, errors="coerce")
    lo, hi = s.quantile([p_low, p_high])
    return s.clip(lo, hi)

# %%
p = players.copy()

import pandas as pd
import numpy as np

# -----------------------
# 1) types
# -----------------------
p["player_id"] = pd.to_numeric(p["player_id"], errors="coerce").astype("Int64")
p["last_season"] = pd.to_numeric(p["last_season"], errors="coerce").astype("Int64")
p["market_value_in_eur"] = pd.to_numeric(p["market_value_in_eur"], errors="coerce")
p["highest_market_value_in_eur"] = pd.to_numeric(p["highest_market_value_in_eur"], errors="coerce")
p["height_in_cm"] = pd.to_numeric(p["height_in_cm"], errors="coerce")

# -----------------------
# 2) dates
# -----------------------
p["date_of_birth"] = pd.to_datetime(p["date_of_birth"], errors="coerce")
p["contract_expiration_date"] = pd.to_datetime(p["contract_expiration_date"], errors="coerce")

# -----------------------
# 3) position bucket
# -----------------------
p["primary_position"] = p["position"]

# -----------------------
# 4) basic sanity flags
# -----------------------
p["flag_missing_dob"] = p["date_of_birth"].isna()
p["flag_missing_pos"] = p["primary_position"].isna()
p["flag_bad_mv"] = (p["market_value_in_eur"] < 0) | (p["market_value_in_eur"] > 5e8)

# -----------------------
# 5) major club filtering (NEW)
# -----------------------
# Pick a club column robustly (your file might name it differently)
club_col_candidates = [
    "club_name", "current_club_name", "current_club", "club",
    "team", "squad", "current_team", "last_club", "club_in_season"
]
club_col = next((c for c in club_col_candidates if c in p.columns), None)

if club_col is None:
    raise KeyError(
        "No club column found. I looked for: "
        + ", ".join(club_col_candidates)
        + ". Check your dataset columns with p.columns and add the correct one."
    )

# Normalize club names for matching
p[club_col] = p[club_col].astype(str).str.strip()

# Reasoning: "major clubs" = consistently elite/top-5-league clubs with sustained UCL presence/brand
MAJOR_CLUBS = {
    # England
    "Manchester City Football Club",
    "Manchester United Football Club",
    "Liverpool Football Club",
    "Chelsea Football Club",
    "Arsenal Football Club",
    "Tottenham Hotspur Football Club",
    "Newcastle United Football Club",
    "West Ham United Football Club",
    "Brighton and Hove Albion Football Club",
    "Wolverhampton Wanderers Football Club",

    # Spain
    "Real Madrid Club de Fútbol",
    "Futbol Club Barcelona",
    "Club Atlético de Madrid S.A.D.",
    "Sevilla Fútbol Club S.A.D.",
    "Valencia Club de Fútbol S. A. D.",
    "Villarreal Club de Fútbol S.A.D.",
    "Real Sociedad de Fútbol S.A.D.",
    "Athletic Club Bilbao",

    # Germany
    "FC Bayern München",
    "Borussia Dortmund",
    "RasenBallsport Leipzig",

    # Italy
    "Juventus Football Club",
    "Football Club Internazionale Milano S.p.A.",
    "Associazione Calcio Milan",
    "Associazione Sportiva Roma",
    "Società Sportiva Calcio Napoli",
    "Atalanta Bergamasca Calcio S.p.a.",
    "Associazione Calcio Fiorentina",

    # France
    "Paris Saint-Germain Football Club",
    "Olympique de Marseille",
    "Olympique Lyonnais",
    "Association sportive de Monaco Football Club",
    "Lille Olympique Sporting Club",

    # Portugal
    "Sport Lisboa e Benfica",
    "Futebol Clube do Porto",
    "Sporting Clube de Portugal",

    # Netherlands
    "AFC Ajax Amsterdam",
    "Feyenoord Rotterdam",
    "Eindhovense Voetbalvereniging Philips Sport Vereniging",

    # Belgium / UCL frequent clubs
    "Royal Sporting Club Anderlecht",
    "Royal Antwerp Football Club",
    "Club Brugge Koninklijke Voetbalvereniging",
}

before_n = len(p)

# Keep only rows where club is one of the major clubs
# (If your dataset contains "FC Barcelona" vs "Barcelona", you'll want a mapping; see note below.)
p = p[p[club_col].isin(MAJOR_CLUBS)].copy()

after_n = len(p)
dropped_n = before_n - after_n

print(f"[Major club filter] Using club column: {club_col}")
print(f"[Major club filter] Dropped {dropped_n} rows ({dropped_n / max(before_n,1):.1%}); remaining {after_n}")

# Optional: verify which clubs remain (should be subset of MAJOR_CLUBS)
print(p[club_col].value_counts().head(25))

# -----------------------
# 6) dedup in case of duplicates
# -----------------------
p["_mv_isna"] = p["market_value_in_eur"].isna().astype(int)
p = (
    p.sort_values(["player_id", "last_season", "_mv_isna"])
     .drop_duplicates(subset=["player_id", "last_season"], keep="first")
     .drop(columns=["_mv_isna"])
)

p.to_csv(INTERIM_DIR / "players_clean_interim.csv", index=False)
p.shape
# Out:
# [Major club filter] Using club column: current_club_name
# [Major club filter] Dropped 30848 rows (89.9%); remaining 3482
# current_club_name
# Atalanta Bergamasca Calcio S.p.a.             164
# Associazione Sportiva Roma                    131
# Football Club Internazionale Milano S.p.A.    124
# Associazione Calcio Fiorentina                111
# West Ham United Football Club                 102
# Juventus Football Club                        100
# Club Atlético de Madrid S.A.D.                 95
# Royal Antwerp Football Club                    94
# Olympique de Marseille                         93
# Associazione Calcio Milan                      91
# Sevilla Fútbol Club S.A.D.                     91
# Chelsea Football Club                          89
# Società Sportiva Calcio Napoli                 89
# Royal Sporting Club Anderlecht                 88
# Brighton and Hove Albion Football Club         88
# Lille Olympique Sporting Club                  86
# ...

# %%
s = perf.copy()

# parse keys/types
s["player_id"] = pd.to_numeric(s["player_id"], errors="coerce").astype("Int64")
s["game_id"] = pd.to_numeric(s["game_id"], errors="coerce").astype("Int64")
s["minutes_played"] = pd.to_numeric(s["minutes_played"], errors="coerce")
s["goals"] = pd.to_numeric(s["goals"], errors="coerce")
s["assists"] = pd.to_numeric(s["assists"], errors="coerce")
s["yellow_cards"] = pd.to_numeric(s["yellow_cards"], errors="coerce")
s["red_cards"] = pd.to_numeric(s["red_cards"], errors="coerce")

# parse date
s["date"] = pd.to_datetime(s["date"], errors="coerce")

# drop rows without critical identifiers or date
s = s.dropna(subset=["player_id", "date"])

# derive season end year
s["season"] = np.where(s["date"].dt.month >= 7,
                       s["date"].dt.year + 1,
                       s["date"].dt.year).astype("int")

# keep only 2013–2023 seasons
s = s[s["season"].between(2013, 2023, inclusive="both")]

s.shape
# Out:
# (1445747, 14)

# %%
agg_cols = {
    "minutes_played": "sum",
    "goals": "sum",
    "assists": "sum",
    "yellow_cards": "sum",
    "red_cards": "sum",
    "game_id": "nunique",  # count matches appeared in
}

season_stats = (s.groupby(["player_id", "season"], as_index=False)
                  .agg(agg_cols)
                  .rename(columns={"game_id": "matches_played"}))

# per90 rates (only meaningful with enough minutes)
season_stats["minutes_played"] = season_stats["minutes_played"].clip(lower=0)

for c in ["goals", "assists", "yellow_cards", "red_cards"]:
    season_stats[f"{c}_per90"] = np.where(season_stats["minutes_played"] >= 450,
                                          90 * season_stats[c] / season_stats["minutes_played"],
                                          np.nan)


season_stats.to_csv(INTERIM_DIR / "season_stats_interim.csv", index=False)
season_stats.shape
# Out:
# (74236, 12)

# %%
# Keep only needed player columns 
p_keep = p[["player_id", "date_of_birth", "primary_position"]].copy()

panel = season_stats.merge(p_keep, on="player_id", how="left")

# age at season end (June 30 of season end-year)
season_end = pd.to_datetime(panel["season"].astype(str) + "-06-30", errors="coerce")
panel["age"] = (season_end - panel["date_of_birth"]).dt.days / 365.25

# sanity flags check if ages are between 15 and 45
panel["flag_bad_age"] = (panel["age"] < 15) | (panel["age"] > 45)
panel["flag_missing_pos"] = panel["primary_position"].isna()

panel.to_csv(PROCESSED_DIR / "player_season_panel.csv", index=False)
panel.shape
# Out:
# (74236, 17)

# %%
valu = pd.read_csv(RAW_DIR / "player_valuations.csv")

valu["player_id"] = pd.to_numeric(valu["player_id"], errors="coerce").astype("Int64")
valu["date"] = pd.to_datetime(valu["date"], errors="coerce")
valu["market_value_in_eur"] = pd.to_numeric(valu["market_value_in_eur"], errors="coerce")
valu = valu.dropna(subset=["player_id", "date", "market_value_in_eur"])

# derive season
valu["season"] = np.where(valu["date"].dt.month >= 7,
                          valu["date"].dt.year + 1,
                          valu["date"].dt.year).astype("int")
valu = valu[valu["season"].between(2013, 2023, inclusive="both")]

# pick one valuation per player-season: closest to June 30 (season end)
season_end_dates = pd.to_datetime(valu["season"].astype(str) + "-06-30", errors="coerce")
valu["days_from_season_end"] = (valu["date"] - season_end_dates).abs().dt.days

valu_season = (valu.sort_values(["player_id","season","days_from_season_end"])
                 .drop_duplicates(["player_id","season"], keep="first")
                 [["player_id","season","market_value_in_eur"]])

# inflation adjustment TODO: add accurate cpi data
cpi_map = {y: 1.0 for y in range(2013, 2024)}
cpi_2023 = 1.0

valu_season["cpi"] = valu_season["season"].map(cpi_map).astype(float)
valu_season["mv_real_2023eur"] = valu_season["market_value_in_eur"] * (cpi_2023 / valu_season["cpi"])

# merge valuations into panel
full = panel.merge(valu_season[["player_id","season","mv_real_2023eur"]], on=["player_id","season"], how="inner")

# compute consecutive-season changes
full = full.sort_values(["player_id","season"])
full["mv_prev"] = full.groupby("player_id")["mv_real_2023eur"].shift(1)
full["season_prev"] = full.groupby("player_id")["season"].shift(1)
full["is_consecutive"] = (full["season"] - full["season_prev"] == 1)

full["delta_log_mv"] = np.log1p(full["mv_real_2023eur"]) - np.log1p(full["mv_prev"])
full["delta_direction"] = (full["delta_log_mv"] >= 0).astype(int)

# keep modeling rows
model_df = full[full["is_consecutive"] & full["mv_prev"].notna()].copy()

# drop bad ages, missing positions, and low-minutes noisy seasons
model_df = model_df[~model_df["flag_bad_age"]]
model_df = model_df[~model_df["flag_missing_pos"]]
model_df = model_df[model_df["minutes_played"] >= 450]

# winsorize to reduce leverage
model_df["minutes_w"] = winsorize(model_df["minutes_played"], 0.01, 0.99)
model_df["delta_log_mv_w"] = winsorize(model_df["delta_log_mv"], 0.01, 0.99)

model_df.to_csv(PROCESSED_DIR / "mv_change_model_dataset.csv", index=False)
model_df.shape
# Out:
# (4750, 25)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
df = pd.read_csv(PROCESSED_DIR / "mv_change_model_dataset.csv")
df.head()
# Out:
#    player_id  season  minutes_played  goals  assists  yellow_cards  red_cards  \
# 0         26    2016            1260      0        0             1          0
# 1         26    2017            1020      0        0             0          0
# 2        132    2014            2232      3        1             9          0
# 3        132    2015             832      3        2             1          0
# 4        410    2014            1934      2        2             4          0
#
#    matches_played  goals_per90  assists_per90  ...  flag_bad_age  \
# 0              14     0.000000       0.000000  ...         False
# 1              11     0.000000       0.000000  ...         False
# 2              38     0.120968       0.040323  ...         False
# 3              23     0.324519       0.216346  ...         False
# 4              27     0.093071       0.093071  ...         False
#
#    flag_missing_pos mv_real_2023eur    mv_prev  season_prev  is_consecutive  \
# ...

# %% [markdown]
# #### Section 1 - Distribution of Season Market Value Changes
#
# Understanding the overall distribution of market value changes is important before modeling. This plot shows how player valuations change between consecutive seasons.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["delta_log_mv"], bins=40)
plt.title("Distribution of Season-to-Season Market Value Changes")
plt.xlabel("Log Change in Market Value")
plt.ylabel("Number of Player-Seasons")
plt.show()

# %% [markdown]
# #### Interpretation
#
# Most observations cluster around zero, indicating that many players experience relatively small changes in market value between seasons. The distribution is slightly right-skewed, meaning that while many players experience small valuation changes, a smaller group of players experience large increases in value. Negative changes also occur, which may reflect aging, declining performance, or reduced playing time. Buttowards the end points you can see that players are more likely to experience steep inclines in salaries that dramatically increase their salary than to experience dramatic drop offs in salary. This could also be due to inflation over time hence the use of log to reduce variance.

# %%
df["delta_direction"].value_counts()
# Out:
# delta_direction
# 1    2652
# 0    2098
# Name: count, dtype: int64

# %%
sns.countplot(x="delta_direction", data=df)
plt.title("Direction of Market Value Change (0 = decrease, 1 = increase)")
plt.show()

# %%
sns.scatterplot(x="minutes_played", y="delta_log_mv", data=df)
plt.title("Minutes Played vs Market Value Change")
plt.show()

# %% [markdown]
# #### Section 2 - Age and Changes in Market Value
#
# Player value often follows a career lifecycle, increasing during early development and declining as players age. The following figure explores the relationship between player age and season-to-season market value change.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="age", y="delta_log_mv", alpha=0.25, s=15)
sns.regplot(data=df, x="age", y="delta_log_mv", scatter=False, color="red", line_kws={"linewidth":2})
plt.title("Age vs Market Value Change")
plt.xlabel("Player Age")
plt.ylabel("Log Change in Market Value")
plt.show()

# %% [markdown]
# #### Interpretation
#
# The relationship suggests that younger players are more likely to experience increases in market value, reflecting their potential for development and longer career horizons. Older players tend to experience smaller increases or declines in valuation, which is consistent with the typical lifecycle of professional soccer players.

# %% [markdown]
# #### Section 3 - Performance and Market Value Change
#
# Offensive performance is one of the most visible indicators of player value. The following analysis explores whether players with higher scoring rates tend to experience larger increases in market value.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x="goals_per90", y="delta_log_mv", alpha=0.25, s=15)
sns.regplot(data=df, x="goals_per90", y="delta_log_mv", scatter=False, color="red", line_kws={"linewidth":2})
plt.title("Goals per 90 Minutes vs Market Value Change")
plt.xlabel("Goals per 90 Minutes")
plt.ylabel("Log Change in Market Value")
plt.show()

# %% [markdown]
# #### Interpretation
# Players with higher goal-scoring rates tend to experience larger increases in market value, although the relationship is noisy. This suggests that offensive production plays an important role in valuation, but other factors such as club prestige, reputation, and playing position also influence market value. You also see a large line at 0 goals per minute. This can be attributed to goals never being scored by goalkeepers/defensemen. You can see that many of them experience large changes in market value even though they are scoring 0 goals tyhroughout a season.

# %% [markdown]
# #### Section 4 - Market Value Changes by Player Position
#
# Different positions contribute differently to team performance and may therefore experience different valuation patterns.

# %%
plt.figure(figsize=(8,5))
df_pos = df[(df["primary_position"].notna()) & (df["primary_position"] != "Missing")]
sns.boxplot(data=df_pos, x="primary_position", y="delta_log_mv")
plt.title("Market Value Change by Player Position")
plt.xlabel("Player Position")
plt.ylabel("Log Change in Market Value")
plt.show()

# %% [markdown]
# #### Interpretation
# The distribution of market value changes varies across positions. Attacking players, particularly forwards, tend to show greater variability in valuation changes, reflecting the premium placed on goal-scoring ability in the transfer market. Defensive positions generally show smaller valuation swings.

# %% [markdown]
# ## Ethics

# %% [markdown]
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
# > This is relevant to our project because soccer player market values are not neutral measures of ability as they are affected by media exposure, league prestige, and subjective evaluation by clubs and analysts. As a result, the data may systematically overrepresent players from major European leagues, while undervaluing players from less visible leagues or countries, which may cause bias into any analysis that treats market value as an objective outcome.
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
# > We acknowledge that market value metrics may overlook non-quantifiable aspects of player contribution, such as leadership or tactical role. These limitations are considered when interpreting results and discussed explicitly in our analysis.
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
# > We recognize the risk that results could be misinterpreted as objective evaluations of player ability. To mitigate this, we clearly state that findings are descriptive and context-dependent, and we discourage any real-world decision-making based on our analysis.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *Actively Participate*
# * *Join weekly meetings*
# * *Ask questions*
# * *Let others know before pushing code to github*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/3  |  7 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Edit, finalize, and submit proposal; Search for datasets |
# | 2/10  |  7 PM |  Do background research on topic | Discuss ideal dataset(s) and ethics |
# | 2/17  | 7 PM  | Finalize Datasets/cleaning data  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 2/24  | 7 PM  | Import & Wrangle Data; EDA | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 3/3  | 7 PM  | Finalize wrangling/EDA; Begin Analysis | Discuss/edit Analysis; Complete project check-in |
# | 3/10  | 7 PM  | Complete analysis; Draft results/conclusion/discussion | Discuss/edit full project |
# | 3/17  | Before 11:59 PM  | Final touch-ups and Final Thoughts | Turn in Final Project & Group Project Surveys |
